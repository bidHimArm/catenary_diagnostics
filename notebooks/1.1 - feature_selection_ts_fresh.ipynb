# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures, load_robot_execution_failures
from tsfresh import extract_features, extract_relevant_features, select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh.feature_extraction import ComprehensiveFCParameters
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# We set the logger to Error level
# This is not recommend for normal use as you can oversee important Warning messages
import logging
logging.basicConfig(level=logging.ERROR)

# %%
field_data = pd.read_csv('../data/interim/field_data.csv', index_col=0)
field_data.head()
# Out:
#     ts      AARD       AARG      AAVD      AAVG        AM          Fc  \
# 0  0.0 -6.569074 -10.717356 -9.113529 -7.193623 -8.398395   59.851273
# 1  1.0 -6.883555  -9.547513 -6.912798 -4.473680 -6.954387   69.203842
# 2  2.0 -6.022359  -6.864442 -8.345452 -4.435100 -6.416838   82.019447
# 3  3.0 -6.869041  -6.433753 -8.650504 -5.939749 -6.973262   96.665985
# 4  4.0 -4.662831  -5.525816 -9.712738 -9.759242 -7.415157  111.383583
#
#         Speed direction   span           id  classes
# 0  160.173004  descente  Span1  run12_Span1  splicer
# 1  160.173004  descente  Span1  run12_Span1  splicer
# 2  160.173004  descente  Span1  run12_Span1  splicer
# 3  160.173004  descente  Span1  run12_Span1  splicer
# 4  160.173004  descente  Span1  run12_Span1  splicer

# %% [markdown]
# # Extract Features

# %%
df = field_data.drop(columns=['Speed', 'direction', 'span', 'classes'])

# %%
extraction_settings = ComprehensiveFCParameters()

# %%
X = extract_features(df, 
                     column_id='id', column_sort='ts',
                     default_fc_parameters=extraction_settings,
                     impute_function= impute)
# Out:
# Feature Extraction: 100%|██████████| 20/20 [01:53<00:00,  5.69s/it]

# %%
X.head()
# Out:
# variable      AARD__abs_energy  AARD__absolute_sum_of_changes  \
# id
# run10_Span1       22869.505976                     426.083997
# run10_Span10      20751.738963                     389.018701
# run10_Span11      23038.622067                     488.985176
# run10_Span12      20680.832175                     407.510224
# run10_Span2       21384.694195                     605.091819
#
# variable      AARD__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# run10_Span1                                           -0.015499
# run10_Span10                                           0.002970
# run10_Span11                                           0.014179
# run10_Span12                                           0.006087
# run10_Span2                                           -0.001021
#
# variable      AARD__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# run10_Span1                                           -0.050271
# run10_Span10                                          -0.070024
# run10_Span11                                           0.011728
# run10_Span12                                          -0.001767
# run10_Span2                                           -0.004073
#
# variable      AARD__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# run10_Span1                                            0.089691
# run10_Span10                                           0.037087
# run10_Span11                                           0.037133
# run10_Span12                                           0.040271
# run10_Span2                                            0.034065
#
# variable      AARD__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# run10_Span1                                           -3.501116
# run10_Span10                                          -5.700340
# run10_Span11                                          -4.983168
# run10_Span12                                          -4.288704
# run10_Span2                                           -3.218167
#
# variable      AARD__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# run10_Span1                                           -0.242578
# run10_Span10                                           0.115396
# run10_Span11                                           0.168974
# run10_Span12                                          -0.295094
# run10_Span2                                           -0.293647
#
# variable      AARD__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# run10_Span1                                           -0.059449
# run10_Span10                                           0.017883
# run10_Span11                                           0.032318
# run10_Span12                                          -0.044697
# run10_Span2                                           -0.053328
#
# variable      AARD__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"  \
# id
# run10_Span1                                            0.042701
# run10_Span10                                           0.027647
# run10_Span11                                           0.033858
# run10_Span12                                           0.025993
# run10_Span2                                            0.031695
#
# variable      AARD__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"  \
# id
# run10_Span1                                           -1.142191
# run10_Span10                                          -4.552589
# run10_Span11                                          -3.242825
# run10_Span12                                          -2.528502
# run10_Span2                                           -1.773919
#
# variable      ...  Fc__symmetry_looking__r_0.9  \
# id            ...
# run10_Span1   ...                          1.0
# run10_Span10  ...                          1.0
# run10_Span11  ...                          1.0
# run10_Span12  ...                          1.0
# run10_Span2   ...                          1.0
#
# variable      Fc__symmetry_looking__r_0.9500000000000001  \
# id
# run10_Span1                                          1.0
# run10_Span10                                         1.0
# run10_Span11                                         1.0
# run10_Span12                                         1.0
# run10_Span2                                          1.0
#
# variable      Fc__time_reversal_asymmetry_statistic__lag_1  \
# id
# run10_Span1                                     500.355680
# run10_Span10                                   1212.113893
# run10_Span11                                  -3097.734683
# run10_Span12                                   2105.924676
# run10_Span2                                    4094.196209
#
# variable      Fc__time_reversal_asymmetry_statistic__lag_2  \
# id
# run10_Span1                                     683.877690
# run10_Span10                                   2919.910774
# run10_Span11                                  -5178.645859
# run10_Span12                                   6306.048466
# run10_Span2                                    7466.705061
#
# variable      Fc__time_reversal_asymmetry_statistic__lag_3  \
# id
# run10_Span1                                     914.524966
# run10_Span10                                   4203.131412
# run10_Span11                                  -5524.571441
# run10_Span12                                  11493.374167
# run10_Span2                                   12297.647040
#
# variable      Fc__value_count__value_-1  Fc__value_count__value_0  \
# id
# run10_Span1                         0.0                       0.0
# run10_Span10                        0.0                       0.0
# run10_Span11                        0.0                       0.0
# run10_Span12                        0.0                       0.0
# run10_Span2                         0.0                       0.0
#
# variable      Fc__value_count__value_1  Fc__variance  \
# id
# run10_Span1                        0.0   1015.993225
# run10_Span10                       0.0    948.927174
# run10_Span11                       0.0   1131.809279
# run10_Span12                       0.0    810.069730
# run10_Span2                        0.0   1116.405135
#
# variable      Fc__variance_larger_than_standard_deviation
# id
# run10_Span1                                           1.0
# run10_Span10                                          1.0
# run10_Span11                                          1.0
# run10_Span12                                          1.0
# run10_Span2                                           1.0
#
# [5 rows x 4536 columns]
